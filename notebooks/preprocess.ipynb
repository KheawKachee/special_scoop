# %%
from pathlib import Path

import pandas as pd

root = Path.cwd()
while not (root / ".git").exists() and root.parent != root:
    root = root.parent

DATA_PATH = root / "data" / "fbref"
files = list(DATA_PATH.glob("*/*.csv"))

ref = DATA_PATH / "references" / "fbref_player_reference.json"
gk_ref = DATA_PATH / "references" / "fbref_keeper_reference.json"
team_ref = DATA_PATH / "references" / "fbref_team_reference.json"

for f in files[:]:
    current_file = Path(f)
    parent_dir = current_file.parent
    file_name = current_file.stem
    year = file_name[-5:]

    print(f"Processing: {file_name}")

    df = pd.read_csv(current_file)

    if "keeper" in file_name:
        ref_df = pd.read_json(gk_ref)
    elif "team" in file_name:
        ref_df = pd.read_json(team_ref)
    else:
        ref_df = pd.read_json(ref)

    ref_df = ref_df.T
    metrics = ref_df.iloc[:, 1].to_dict()

    keys = metrics.keys()
    print(keys)

    for k in keys:
        m = metrics[k]
        _df = df.copy()
        _df = _df[m]

        if "team" not in file_name:
            pos = _df["position"].str.replace(" ", "", regex=False)

            dummies = pos.str.get_dummies(sep=",")

            dummies = dummies.reindex(columns=["GK", "DF", "MF", "FW"], fill_value=0)

            dummies = dummies.add_prefix("position_")

            _df = pd.concat([_df.drop(columns="position"), dummies], axis=1)

        output_dir = parent_dir / year
        output_dir.mkdir(parents=True, exist_ok=True)

        # Save file
        json_path = output_dir / f"{file_name + '_' + k.split('_')[-1]}.json"
        print(f"Saving to: {json_path}")
        _df.to_json(json_path, orient="records", indent=4)
# Out:
# Processing: PL_team_22_23
# dict_keys(['team_all_in_one', 'team_shooting', 'team_passing', 'team_passing_types', 'team_gca', 'team_defense', 'team_possession', 'team_misc', 'team_playing_time', 'team_keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_misc.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_time.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/22_23/PL_team_22_23_adv.json
# Processing: PL_team_23_24
# dict_keys(['team_all_in_one', 'team_shooting', 'team_passing', 'team_passing_types', 'team_gca', 'team_defense', 'team_possession', 'team_misc', 'team_playing_time', 'team_keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_misc.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_time.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/23_24/PL_team_23_24_adv.json
# Processing: PL_team_25_26
# dict_keys(['team_all_in_one', 'team_shooting', 'team_passing', 'team_passing_types', 'team_gca', 'team_defense', 'team_possession', 'team_misc', 'team_playing_time', 'team_keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_misc.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_time.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/25_26/PL_team_25_26_adv.json
# Processing: PL_team_21_22
# dict_keys(['team_all_in_one', 'team_shooting', 'team_passing', 'team_passing_types', 'team_gca', 'team_defense', 'team_possession', 'team_misc', 'team_playing_time', 'team_keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_misc.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_time.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/21_22/PL_team_21_22_adv.json
# Processing: PL_team_24_25
# dict_keys(['team_all_in_one', 'team_shooting', 'team_passing', 'team_passing_types', 'team_gca', 'team_defense', 'team_possession', 'team_misc', 'team_playing_time', 'team_keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_misc.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_time.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/24_25/PL_team_24_25_adv.json
# Processing: PL_team_20_21
# dict_keys(['team_all_in_one', 'team_shooting', 'team_passing', 'team_passing_types', 'team_gca', 'team_defense', 'team_possession', 'team_misc', 'team_playing_time', 'team_keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_misc.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_time.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_team/20_21/PL_team_20_21_adv.json
# Processing: PL_outfield_24_25
# dict_keys(['all_in_one', 'standard_stats', 'shooting', 'passing', 'passing_types', 'gca', 'defense', 'possession', 'misc'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_stats.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/24_25/PL_outfield_24_25_misc.json
# Processing: PL_outfield_20_21
# dict_keys(['all_in_one', 'standard_stats', 'shooting', 'passing', 'passing_types', 'gca', 'defense', 'possession', 'misc'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_stats.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/20_21/PL_outfield_20_21_misc.json
# Processing: PL_outfield_25_26
# dict_keys(['all_in_one', 'standard_stats', 'shooting', 'passing', 'passing_types', 'gca', 'defense', 'possession', 'misc'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_stats.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/25_26/PL_outfield_25_26_misc.json
# Processing: PL_outfield_21_22
# dict_keys(['all_in_one', 'standard_stats', 'shooting', 'passing', 'passing_types', 'gca', 'defense', 'possession', 'misc'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_stats.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/21_22/PL_outfield_21_22_misc.json
# Processing: PL_outfield_22_23
# dict_keys(['all_in_one', 'standard_stats', 'shooting', 'passing', 'passing_types', 'gca', 'defense', 'possession', 'misc'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_stats.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/22_23/PL_outfield_22_23_misc.json
# Processing: PL_outfield_23_24
# dict_keys(['all_in_one', 'standard_stats', 'shooting', 'passing', 'passing_types', 'gca', 'defense', 'possession', 'misc'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_one.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_stats.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_shooting.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_passing.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_types.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_gca.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_defense.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_possession.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_outfield/23_24/PL_outfield_23_24_misc.json
# Processing: PL_keeper_23_24
# dict_keys(['keepers', 'keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/23_24/PL_keeper_23_24_keepers.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/23_24/PL_keeper_23_24_adv.json
# Processing: PL_keeper_21_22
# dict_keys(['keepers', 'keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/21_22/PL_keeper_21_22_keepers.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/21_22/PL_keeper_21_22_adv.json
# Processing: PL_keeper_22_23
# dict_keys(['keepers', 'keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/22_23/PL_keeper_22_23_keepers.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/22_23/PL_keeper_22_23_adv.json
# Processing: PL_keeper_20_21
# dict_keys(['keepers', 'keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/20_21/PL_keeper_20_21_keepers.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/20_21/PL_keeper_20_21_adv.json
# Processing: PL_keeper_24_25
# dict_keys(['keepers', 'keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/24_25/PL_keeper_24_25_keepers.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/24_25/PL_keeper_24_25_adv.json
# Processing: PL_keeper_25_26
# dict_keys(['keepers', 'keepers_adv'])
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/25_26/PL_keeper_25_26_keepers.json
# Saving to: /home/kheaw/projects/special_scoop/data/fbref/PL_keeper/25_26/PL_keeper_25_26_adv.json
